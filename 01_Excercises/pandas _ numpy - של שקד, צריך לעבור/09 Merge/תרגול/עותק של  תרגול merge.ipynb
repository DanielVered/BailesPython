# %%
import pandas as pdb

# %%
week1 = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/Restaurant%20-%20Week%201%20Sales.csv")
week2 = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/Restaurant%20-%20Week%202%20Sales.csv")
customers = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/Restaurant%20-%20Customers.csv")
foods = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/Restaurant%20-%20Foods.csv")

# %%
# הציגו עבור כל לקוח את רכישותיו בשבוע ה-2. מטבלת הלקוחות הציגו רק את עמודת השם הפרטי ושם המשפחה

# %%
# ייבאו מחדש את טבלת הלקוחות, ועכשיו הציבו את עמודת ה-ID כאינדקס בטבלת הלקוחות.
# הציגו עכשיו עבור כל מכירה בשבוע 2 את שם ושם המשפחה של הלקוח שביצע את אותה רכישה.

# %%
# הפכו את עמודת מזהה האוכל בטבלאות של המכירות בשבוע 1 ובשבוע 2 לאינדקס
# כעת הצמידו בין שתי הטבלאות כדי להציג את כלל התוצאות משתיהן ביחד, והציגו עמודה שאומרת עבור כל רשומה באיזו מהטבלאות היא הופיעה.

# %%
# השתמשו בפונקציה join  כדי להוסיף את עמודת המחיר מטבלת האוכל לטבלה של מכירות שבוע 1

# %%
# בצעו cross join בין הטבלאות הבאות:
left = pd.DataFrame({'col1' :['A', 'B', 'C'], 'col2' : [1,2,3]})
right = pd.DataFrame({'col1' :['X', 'Y', 'Z'], 'col2' : [20,30,50]})

# %%
# חברו את הרשומות מהטבלאות של המכירות בשבוע 2 ובשבוע 1 (union)
