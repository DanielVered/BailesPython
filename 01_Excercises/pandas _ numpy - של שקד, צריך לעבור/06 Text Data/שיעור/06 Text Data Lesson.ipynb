# %% [markdown]
# <img src="Images\Slide1.PNG" />

# %%
import pandas as pd

# %% [markdown]
# <img src="Images\Slide2.PNG" />

# %%
"Python Is the Best".lower()
# Out:
# 'python is the best'

# %%
"Python Is the Best".upper()
# Out:
# 'PYTHON IS THE BEST'

# %%
"python is the best".title()
# Out:
# 'Python Is The Best'

# %% [markdown]
# <img src="Images\Slide3.PNG" />

# %% [markdown]
# <div dir="rtl">
# # הערה: נקרא גם accessor

# %%
# ?pd.Series.str

# %%
chicago = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.dropna(inplace=True)
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
chicago.describe()
# Out:
#                   Name  Position Title Department Employee Annual Salary
# count            32062           32062      32062                  32062
# unique           31776            1093         35                   1156
# top     PEREZ,  JOSE A  POLICE OFFICER     POLICE              $87384.00
# freq                 4            9184      12618                   2394

# %%
chicago["Department"].nunique()
# Out:
# 35

# %%
chicago["Department"].count()
# Out:
# 32062

# %% [markdown]
# ## The `str.lower(), str.upper(), str.title(), str.len()` Methods

# %%
"HEllo WOrld".lower()

# %%
"Hello World".upper()

# %%
"HEllo WOrld".title()

# %%
type(chicago['Position Title'])
# Out:
# pandas.core.series.Series

# %%
type(chicago['Position Title'].str)
# Out:
# pandas.core.strings.StringMethods

# %%
chicago['Position Title'].dtype
# Out:
# dtype('O')

# %%
chicago["Position Title"].str.lower()

# %%
chicago["Position Title"].str.title()

# %%
chicago.head()

# %%
chicago["Position Title"] = chicago["Position Title"].str.title()

# %%
chicago.head()
# Out:
#                   Name  ... Employee Annual Salary
# 0      AARON,  ELVIA J  ...              $90744.00
# 1    AARON,  JEFFERY M  ...              $84450.00
# 2       AARON,  KARINA  ...              $84450.00
# 3  AARON,  KIMBERLEI R  ...              $89880.00
# 4  ABAD JR,  VICENTE M  ...             $106836.00
#
# [5 rows x 4 columns]

# %%
chicago["Position Title"].str.len()
# Out:
# 0        16
# 1        14
# 2        14
# 3        24
# 4        17
#          ..
# 32057    30
# 32058    14
# 32059    14
# 32060    14
# 32061    23
# Name: Position Title, Length: 32062, dtype: int64

# %% [markdown]
# ## The `str.replace()` Method

# %%
chicago = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.dropna(inplace=True)
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
# new_salary  = chicago['Employee Annual Salary'].copy()
new_salary = pd.Series(['s',"6","6"])
new_salary.replace('6', '999')
# Out:
# 0      s
# 1    999
# 2    999
# dtype: object

# %%
chicago["Employee Annual Salary"].str.replace("$","^^")
# Out:
# 0         ^^90744.00
# 1         ^^84450.00
# 2         ^^84450.00
# 3         ^^89880.00
# 4        ^^106836.00
#             ...
# 32057     ^^99528.00
# 32058     ^^87384.00
# 32059     ^^84450.00
# 32060     ^^87384.00
# 32061    ^^113664.00
# Name: Employee Annual Salary, Length: 32062, dtype: object

# %%
chicago["Employee Annual Salary"].dtype
# Out:
# dtype('O')

# %%
chicago["Employee Annual Salary"].str.replace("$","").astype("float")
# Out:
# 0         90744.0
# 1         84450.0
# 2         84450.0
# 3         89880.0
# 4        106836.0
#            ...
# 32057     99528.0
# 32058     87384.0
# 32059     84450.0
# 32060     87384.0
# 32061    113664.0
# Name: Employee Annual Salary, Length: 32062, dtype: float64

# %%
chicago["Employee Annual Salary"] = chicago["Employee Annual Salary"].str.replace("$","").astype("float")

# %%
chicago.head()

# %%
chicago.describe()

# %% [markdown]
# ## Filtering with String Methods `str.replace()`

# %%
chicago = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.dropna(inplace=True)
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
mask = chicago["Position Title"].str.lower().str.contains("water")

# %%
mask.head(10)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Position Title, dtype: bool

# %%
len(mask)

# %%
len(chicago)

# %%
type(chicago["Position Title"].str.lower())

# %%
mask = chicago["Position Title"].str.lower().str.startswith("water")

# %%
chicago[mask]

# %%
mask = chicago["Position Title"].str.lower().str.endswith("ist")

# %%
chicago[mask]

# %% [markdown]
# ## The `str.strip()` , `str.lstrip()` , `str.rstrip()` Methods

# %%
chicago = pd.read_csv("chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)

# %%
? str.rstrip()

# %%
"        HI!".lstrip()

# %%
"HI!    ".rstrip()

# %%
"        HI!       ".strip()

# %%
chicago['Name'] = chicago['Name'] + "               "

# %%
chicago.head()

# %%
chicago["Name"].str.len().head(15)

# %%
chicago["Name"].str.lstrip().str.len().head(15)

# %%
chicago["Name"].str.rstrip().str.len().head(15)

# %%
chicago["Name"].str.strip().str.len().head(15)

# %%
chicago["Name"].str.strip().head()

# %% [markdown]
# ## String Methods on Index and Columns

# %%
chicago = pd.read_csv("chicago.csv", index_col="Name")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)

# %%
chicago.index.str.strip().str.title()

# %%
chicago.index = chicago.index.str.strip().str.title()

# %%
chicago.head()

# %%
chicago.columns = chicago.columns.str.upper()

# %%
chicago.head()

# %% [markdown]
# ## The `str.split()`, `str.get()`  Methods

# %%
chicago = pd.read_csv("https://raw.githubusercontent.com/kita8/PythonCsvData/main/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
"Hello, My Name is nit and Teach Pandas".split()
# Out:
# ['Hello,', 'My', 'Name', 'is', 'nit', 'and', 'Teach', 'Pandas']

# %%
chicago["Name"].str.split(",")
# Out:
# 0            [AARON,   ELVIA J]
# 1          [AARON,   JEFFERY M]
# 2             [AARON,   KARINA]
# 3        [AARON,   KIMBERLEI R]
# 4        [ABAD JR,   VICENTE M]
#                   ...
# 32058     [ZYGOWICZ,   PETER J]
# 32059      [ZYMANTAS,   MARK E]
# 32060    [ZYRKOWSKI,   CARLO E]
# 32061    [ZYSKOWSKI,   DARIUSZ]
# 32062                       NaN
# Name: Name, Length: 32063, dtype: object

# %%
chicago["Name"].str.split(",")[0]
# Out:
# ['AARON', '  ELVIA J']

# %%
chicago["Name"].str.split(",")[0][0]
# Out:
# 'AARON'

# %%
chicago["Name"].str.split(",").get(0)
# Out:
# ['AARON', '  ELVIA J']

# %%
chicago["Name"].str.split(",").str.get(0)
# Out:
# 0            AARON
# 1            AARON
# 2            AARON
# 3            AARON
# 4          ABAD JR
#            ...
# 32058     ZYGOWICZ
# 32059     ZYMANTAS
# 32060    ZYRKOWSKI
# 32061    ZYSKOWSKI
# 32062          NaN
# Name: Name, Length: 32063, dtype: object

# %%
# ?pd.Series.get()

# %%
# ?pd.Series.str.get()

# %%
chicago.insert(0,"Last Name",value=chicago["Name"].str.split(",").str.get(1))

# %%
chicago.add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-36ffd48d71c9> in <module>()
# ----> 1 chicago.add()
#
# TypeError: f() missing 1 required positional argument: 'other'

# %%
chicago.insert(0,"First Name",value=chicago["Name"].str.split(",").str.get(0))

# %%
chicago.drop(columns='Name',inplace=True)

# %%
chicago.head()

# %%
chicago = pd.read_csv("chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)

# %%
chicago["Name"].str.split(",").str.get(1).str.split().str.get(1)

# %%
chicago["Name"].str.split(",").str.get(0).value_counts().head(5)

# %%
chicago = pd.read_csv("chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)

# %%
chicago["Name"].str.split(",", expand = True)

# %%
chicago[["First Name","Last Name"]] = chicago["Name"].str.split(",", expand = True)

# %%
chicago.head()

# %%
chicago["Position Title"].str.split(expand = True).head(10)

# %%
chicago["Position Title"].str.split(n=1,expand = True).head(10)

# %%
# ?pd.Series.str.count

# %%
chicago["Position Title"].str.count("A").head(10)

# %%
chicago["Position Title"].str.count("ENGINEER").head(10)

# %%
chicago.insert(0,"Last Name",value=chicago["Name"].str.split(",").str.get(1))

# %%
chicago.add(["s"], axis='index')

# %%
chicago.tail()

# %%
chicago = chicago.append({"Last Name":"Ben Izhak", "Name":"Amir", "Position Title":"DX", "Department":"Team Y", "Employee Annual Salary":"$-2"}, ignore_index=True)

# %%
chicago.append(["Ben Izhak","Amir", "DX","Team Y","$-2"], ignore_index=True)
